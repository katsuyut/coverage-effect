# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
D = 0.122 # D
uconv1 = 3.33564e-30 # C·m/D
D = D*uconv1 # C·m
D
# Out:
# 4.0694808e-31

# %%
h = 1.13E-10 # m
q = D/h # C
q
# Out:
# 3.601310442477876e-21

# %%
k = 8.99E+09 # N·m2·C−2
uconv2 = 6.24E+18 # eV/J

# %%
xrange = np.linspace(1.5,5)*1e-10

# %%
V = 2 * k * q**2 * ((1/xrange - 1/(xrange**2 + h**2)**0.5)) * uconv2

# %%
plt.plot(xrange, V)
plt.xlabel('distance (m)')
plt.ylabel('Energy (eV)')
plt.show()

# %%
COint = np.array([
[1.5, 10.71997861],
[1.57142857143, 9.72633773],
[1.64285714286, 7.90668198],
[1.71428571429, 6.27714391],
[1.78571428571, 4.99856638],
[1.85714285714, 3.99166128],
[1.92857142857, 3.19361178],
[2, 2.55573681],
[2.07142857143, 2.04568822],
[2.14285714286, 1.63847064],
[2.21428571429, 1.31469335],
[2.28571428571, 1.05552327],
[2.35714285714, 0.84931688],
[2.42857142857, 0.6849566],
[2.5, 0.553642810000003],
[2.57142857143, 0.445492850000001],
[2.64285714286, 0.357064940000001],
[2.71428571429, 0.284980170000001],
[2.78571428571, 0.227157770000002],
[2.85714285714, 0.179197200000001],
[2.92857142857, 0.14073136],
[3, 0.110536240000002],
[3.07142857143, 0.0874181800000002],
[3.14285714286, 0.0677206300000002],
[3.21428571429, 0.0514143000000011],
[3.28571428571, 0.0383049900000003],
[3.35714285714, 0.0281186400000024],
[3.42857142857, 0.0188682700000022],
[3.5, 0.0110454200000021],
[3.57142857143, 0.00541066000000257],
[3.64285714286, 0.00164789000000098],
[3.71428571429, -0.00153189999999981],
[3.78571428571, -0.00430211999999841],
[3.85714285714, -0.00564304999999976],
[3.92857142857, -0.00594590999999767],
[4, -0.00605861999999746],
[4.07142857143, -0.00681759999999798],
[4.14285714286, -0.00654484999999738],
[4.21428571429, -0.0056986099999996],
[4.28571428571, -0.00451832999999979],
[4.35714285714, -0.00469633999999886],
[4.42857142857, -0.00401554999999831],
[4.5, -0.00300500999999898],
[4.57142857143, -0.00163652999999897],
[4.64285714286, -0.00203497000000041],
[4.71428571429, -0.00172087999999704],
[4.78571428571, -0.00111725999999734],
[4.85714285714, 4.72000000009132E-05],
[4.92857142857, -0.000571649999997703],
[5, -0.000549859999999569],
])

# %%
Hint = np.array([
[0.2, 28.41474509],
[0.297959183673, 7.76998049],
[0.395918367347, -0.72389511],
[0.49387755102, -4.44882713],
[0.591836734694, -6.02121336],
[0.689795918367, -6.56817818],
[0.787755102041, -6.60850273],
[0.885714285714, -6.38578114],
[0.983673469388, -6.02691442],
[1.08163265306, -5.59746494],
[1.17959183673, -5.14074136],
[1.27755102041, -4.68133292],
[1.37551020408, -4.23780887],
[1.47346938776, -3.81610951],
[1.57142857143, -3.42866742],
[1.6693877551, -3.06706659],
[1.76734693878, -2.73419021],
[1.86530612245, -2.42972673],
[1.96326530612, -2.15352751],
[2.0612244898, -1.90465462],
[2.15918367347, -1.68126892],
[2.25714285714, -1.48092527],
[2.35510204082, -1.30065986],
[2.45306122449, -1.14028824],
[2.55102040816, -0.99673139],
[2.64897959184, -0.86925362],
[2.74693877551, -0.75688682],
[2.84489795918, -0.65759593],
[2.94285714286, -0.57002318],
[3.04081632653, -0.49360855],
[3.1387755102, -0.42868212],
[3.23673469388, -0.36636801],
[3.33469387755, -0.30783483],
[3.43265306122, -0.25476912],
[3.5306122449, -0.20738566],
[3.62857142857, -0.16914089],
[3.72653061224, -0.13588895],
[3.82448979592, -0.10841786],
[3.92244897959, -0.08580661],
[4.02040816327, -0.06813958],
[4.11836734694, -0.05426213],
[4.21632653061, -0.04309277],
[4.31428571429, -0.0341571],
[4.41224489796, -0.02696742],
[4.51020408163, -0.02125451],
[4.60816326531, -0.01678227],
[4.70612244898, -0.01330971],
[4.80408163265, -0.01058518],
[4.90204081633, -0.00841115000000003],
[5, -0.00665293],
])

# %%
plt.plot(COint[:,0]/1e10, COint[:,1])
plt.plot(xrange, V)
plt.xlabel('distance [m]')
plt.ylabel('Energy [eV]')
plt.legend(['VASP', 'dipole'])
plt.title('COinteraction')
plt.ylim(0,1)
plt.show()

# %%
plt.plot(Hint[:,0]/1e10, Hint[:,1])
plt.xlabel('distance [m]')
plt.ylabel('Energy [eV]')
plt.title('H interaction')
plt.legend(['VASP'])
plt.ylim(-1,0)
plt.show()

# %%
plt.rcParams["font.size"] = 14
plt.plot(COint[:,0]/1e10, COint[:,1])
# plt.plot(xrange, V)
plt.xlabel('distance (m)')
plt.ylabel('Interaction energy (eV)')
# plt.legend(['VASP', 'dipole'])
# plt.title('COinteraction')
# plt.ylim(0,1)
plt.savefig('coint.eps',format='eps')
plt.show()
