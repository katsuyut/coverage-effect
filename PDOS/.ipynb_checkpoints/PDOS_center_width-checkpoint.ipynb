# %%
# %matplotlib inline
import numpy as np
from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.core import Spin, Orbital, OrbitalType
import matplotlib.pyplot as plt
import os
# import pymatgen.electronic_structure.dos

# %%
def get_dos_info(str_num, site_type):
    site_spd_dos = cdos.get_site_spd_dos(structure[str_num])
    dos = site_spd_dos[OrbitalType[site_type]].densities[Spin.up]
    ene = site_spd_dos[OrbitalType[site_type]].energies
    
    ##### code from DFT book by J. Kitchin #####
    Nstates = np.trapz(dos, ene)
    occupied = ene <= 0.0
    N_occupied_states = np.trapz(dos[occupied], ene[occupied])
    # first moment
    ed = np.trapz(ene * dos, ene) / Nstates

    # second moment
    wd2 = np.trapz(ene**2 * dos, ene) / Nstates

    print('Total # states = {0:1.2f}'.format(Nstates))
    print('number of occupied states = {0:1.2f}'.format(N_occupied_states))
    print('d-band center = {0:1.2f} eV'.format(ed))
    print('d-band width  = {0:1.2f} eV'.format(np.sqrt(wd2)))

    # plot the d-band
    plt.plot(ene, dos, label='$d$-orbitals')

    # plot the occupied states in shaded gray
    plt.fill_between(x=ene[occupied],
                     y1=dos[occupied],
                     y2=np.zeros(dos[occupied].shape),
                     color='gray', alpha=0.25)

    plt.xlabel('$E - E_f$ (eV)')
    plt.ylabel('DOS (arbitrary units)')
    plt.show()
    ##### code from DFT book by J. Kitchin #####
    
    return Nstates, dos, ene

# %%
v = Vasprun("./Cu_111_u2/vasprun.xml")
# v = Vasprun("./Cu_111_u2_no01_CO_n1_d8/vasprun.xml")
cdos = v.complete_dos
structure = cdos.structure

# str_num: 1~11:lower layer, 12:[0,0,0], 13~15:other str_num = 15, 16:C, 17:O
str_num = 12
site_type = 'd'

for i in range(12,14): # len(structure)
    Nstate, dos, ene = get_dos_info(i, site_type)
# Out:
# Total # states = 10.01
# number of occupied states = 9.59
# d-band center = -2.91 eV
# d-band width  = 3.31 eV
# Total # states = 10.01
# number of occupied states = 9.59
# d-band center = -2.91 eV
# d-band width  = 3.31 eV

# %%
# v = Vasprun("./Cu_111_u2/vasprun.xml")
v = Vasprun("./Cu_111_u2_no01_CO_n1_d8/vasprun.xml")
cdos = v.complete_dos
structure = cdos.structure

# str_num: 1~11:lower layer, 12:[0,0,0], 13~15:other str_num = 15, 16:C, 17:O
str_num = 12
site_type = 'd'

for i in range(12,14): # len(structure)
    Nstate, dos, ene = get_dos_info(i, site_type)
# Out:
# Total # states = 10.25
# number of occupied states = 9.54
# d-band center = -3.53 eV
# d-band width  = 4.07 eV
# Total # states = 9.94
# number of occupied states = 9.56
# d-band center = -2.69 eV
# d-band width  = 3.05 eV

# %%
v = Vasprun("./Pt_111_u2/vasprun.xml")
# v = Vasprun("./Cu_111_u2_no01_CO_n1_d8/vasprun.xml")
cdos = v.complete_dos
structure = cdos.structure

# str_num: 1~11:lower layer, 12:[0,0,0], 13~15:other str_num = 15, 16:C, 17:O
str_num = 12
site_type = 'd'

for i in range(12,14): # len(structure)
    Nstate, dos, ene = get_dos_info(i, site_type)
# Out:
# Total # states = 8.99
# number of occupied states = 8.04
# d-band center = -2.11 eV
# d-band width  = 2.87 eV
# Total # states = 9.00
# number of occupied states = 8.04
# d-band center = -2.10 eV
# d-band width  = 2.88 eV

# %%
# v = Vasprun("./Pt_111_u2/vasprun.xml")
v = Vasprun("./Pt_111_u2_no01_CO_n1_d9/vasprun.xml")
cdos = v.complete_dos
structure = cdos.structure

# str_num: 1~11:lower layer, 12:[0,0,0], 13~15:other str_num = 15, 16:C, 17:O
str_num = 12
site_type = 'd'

for i in range(12,14): # len(structure)
    Nstate, dos, ene = get_dos_info(i, site_type)
# Out:
# Total # states = 9.26
# number of occupied states = 7.60
# d-band center = -2.79 eV
# d-band width  = 4.12 eV
# Total # states = 9.01
# number of occupied states = 7.35
# d-band center = -1.79 eV
# d-band width  = 2.72 eV
