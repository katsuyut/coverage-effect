# %%
from MAUtil import *
from MAPost import *
from MAInit import *
import re

# %%
env = 'local'
files = os.listdir('./init/')
# files = os.listdir('./database/')
chosen = []

for i in range(len(files)):
    if 'Cu' in files[i] or 'Pt' in files[i]:
        print(i, files[i])
        chosen.append(files[i])
# Out:
# 552 Cu_100_u2_RPBE.traj
# 553 Cu_100_u2_RPBE_no001_CO_n1_d8.traj
# 554 Cu_100_u2_RPBE_no002_CO_n2_d3.traj
# 555 Cu_100_u2_RPBE_no003_CO_n3_d3.traj
# 556 Cu_100_u2_RPBE_no004_CO_n4_d3.traj
# 557 Cu_100_u2_RPBE_no005_CO_n3_d3.traj
# 558 Cu_100_u2_RPBE_no006_CO_n4_d3.traj
# 559 Cu_100_u2_RPBE_no007_CO_n2_d3.traj
# 560 Cu_100_u2_RPBE_no008_CO_n2_d3.traj
# 561 Cu_100_u2_RPBE_no009_CO_n3_d3.traj
# 562 Cu_100_u2_RPBE_no010_CO_n1_d8.traj
# 563 Cu_100_u2_RPBE_no011_CO_n2_d3.traj
# 564 Cu_100_u2_RPBE_no012_CO_n3_d3.traj
# 565 Cu_100_u2_RPBE_no013_CO_n4_d3.traj
# 566 Cu_100_u2_RPBE_no014_CO_n2_d3.traj
# 567 Cu_100_u2_RPBE_no015_CO_n3_d3.traj
# 568 Cu_100_u2_RPBE_no016_CO_n4_d3.traj
# 569 Cu_100_u2_RPBE_no017_CO_n3_d3.traj
# 570 Cu_100_u2_RPBE_no018_CO_n2_d3.traj
# 571 Cu_100_u2_RPBE_no019_CO_n2_d3.traj
# 572 Cu_100_u2_RPBE_no020_CO_n1_d8.traj
# 573 Cu_100_u2_RPBE_no021_CO_n2_d3.traj
# 574 Cu_100_u2_RPBE_no022_CO_n3_d3.traj
# 575 Cu_100_u2_RPBE_no023_CO_n4_d3.traj
# 576 Cu_100_u2_RPBE_no024_CO_n2_d3.traj
# 577 Cu_100_u3_RPBE.traj
# 578 Cu_100_u3_RPBE_no001_CO_n1_d13.traj
# 579 Cu_100_u3_RPBE_no002_CO_n1_d13.traj
# 580 Cu_100_u3_RPBE_no003_CO_n1_d13.traj
# 581 Cu_110_u2_RPBE.traj
# 582 Cu_110_u2_RPBE_no001_CO_n1_d8.traj
# 583 Cu_110_u2_RPBE_no002_CO_n2_d5.traj
# 584 Cu_110_u2_RPBE_no003_CO_n3_d3.traj
# 585 Cu_110_u2_RPBE_no004_CO_n4_d3.traj
# 586 Cu_110_u2_RPBE_no005_CO_n3_d3.traj
# 587 Cu_110_u2_RPBE_no006_CO_n4_d3.traj
# 588 Cu_110_u2_RPBE_no007_CO_n2_d5.traj
# 589 Cu_110_u2_RPBE_no008_CO_n3_d3.traj
# 590 Cu_110_u2_RPBE_no009_CO_n4_d3.traj
# 591 Cu_110_u2_RPBE_no011_CO_n2_d5.traj
# 592 Cu_110_u2_RPBE_no012_CO_n3_d3.traj
# 593 Cu_110_u2_RPBE_no013_CO_n2_d5.traj
# 594 Cu_110_u2_RPBE_no014_CO_n3_d3.traj
# 595 Cu_110_u2_RPBE_no015_CO_n1_d8.traj
# 596 Cu_110_u2_RPBE_no016_CO_n2_d5.traj
# 597 Cu_110_u2_RPBE_no017_CO_n3_d3.traj
# 598 Cu_110_u2_RPBE_no018_CO_n4_d3.traj
# 599 Cu_110_u2_RPBE_no019_CO_n3_d3.traj
# 600 Cu_110_u2_RPBE_no020_CO_n4_d3.traj
# 601 Cu_110_u2_RPBE_no021_CO_n2_d5.traj
# 602 Cu_110_u2_RPBE_no022_CO_n3_d3.traj
# 603 Cu_110_u2_RPBE_no023_CO_n4_d3.traj
# 604 Cu_110_u2_RPBE_no024_CO_n3_d3.traj
# 605 Cu_110_u2_RPBE_no025_CO_n2_d5.traj
# 606 Cu_110_u2_RPBE_no026_CO_n3_d3.traj
# 607 Cu_110_u2_RPBE_no027_CO_n2_d5.traj
# 608 Cu_110_u2_RPBE_no028_CO_n2_d5.traj
# 609 Cu_110_u2_RPBE_no029_CO_n1_d8.traj
# 610 Cu_110_u2_RPBE_no030_CO_n2_d5.traj
# 611 Cu_110_u2_RPBE_no031_CO_n3_d3.traj
# 612 Cu_110_u2_RPBE_no032_CO_n4_d3.traj
# 613 Cu_110_u2_RPBE_no033_CO_n2_d5.traj
# 614 Cu_110_u2_RPBE_no034_CO_n2_d5.traj
# 615 Cu_110_u2_RPBE_no035_CO_n1_d8.traj
# 616 Cu_110_u2_RPBE_no036_CO_n2_d5.traj
# 617 Cu_110_u2_RPBE_no037_CO_n3_d3.traj
# 618 Cu_110_u2_RPBE_no038_CO_n4_d3.traj
# 619 Cu_110_u2_RPBE_no039_CO_n2_d5.traj
# 620 Cu_110_u2_RPBE_no040_CO_n2_d5.traj
# 621 Cu_110_u3_RPBE.traj
# 622 Cu_110_u3_RPBE_no001_CO_n1_d13.traj
# 623 Cu_110_u3_RPBE_no002_CO_n1_d13.traj
# 624 Cu_110_u3_RPBE_no003_CO_n1_d13.traj
# 625 Cu_110_u3_RPBE_no004_CO_n1_d13.traj
# 626 Cu_111_u2_RPBE.traj
# 627 Cu_111_u2_RPBE_no001_CO_n1_d8.traj
# 628 Cu_111_u2_RPBE_no002_CO_n2_d3.traj
# 629 Cu_111_u2_RPBE_no003_CO_n3_d3.traj
# 630 Cu_111_u2_RPBE_no004_CO_n4_d3.traj
# 631 Cu_111_u2_RPBE_no005_CO_n2_d3.traj
# 632 Cu_111_u2_RPBE_no006_CO_n3_d3.traj
# 633 Cu_111_u2_RPBE_no007_CO_n2_d3.traj
# 634 Cu_111_u2_RPBE_no008_CO_n1_d8.traj
# 635 Cu_111_u2_RPBE_no009_CO_n2_d3.traj
# 636 Cu_111_u2_RPBE_no010_CO_n3_d3.traj
# 637 Cu_111_u2_RPBE_no011_CO_n4_d3.traj
# 638 Cu_111_u2_RPBE_no012_CO_n2_d3.traj
# 639 Cu_111_u2_RPBE_no013_CO_n2_d3.traj
# 640 Cu_111_u2_RPBE_no014_CO_n2_d3.traj
# 641 Cu_111_u2_RPBE_no015_CO_n1_d8.traj
# 642 Cu_111_u2_RPBE_no016_CO_n2_d3.traj
# 643 Cu_111_u2_RPBE_no017_CO_n3_d3.traj
# 644 Cu_111_u2_RPBE_no018_CO_n4_d3.traj
# 645 Cu_111_u2_RPBE_no019_CO_n2_d3.traj
# 646 Cu_111_u2_RPBE_no020_CO_n1_d8.traj
# 647 Cu_111_u2_RPBE_no021_CO_n2_d3.traj
# 648 Cu_111_u2_RPBE_no022_CO_n3_d3.traj
# 649 Cu_111_u2_RPBE_no023_CO_n4_d3.traj
# 650 Cu_111_u3_RPBE.traj
# 651 Cu_111_u3_RPBE_no001_CO_n1_d13.traj
# 652 Cu_111_u3_RPBE_no002_CO_n1_d13.traj
# 653 Cu_111_u3_RPBE_no003_CO_n1_d13.traj
# 654 Cu_111_u3_RPBE_no004_CO_n1_d13.traj
# 655 Cu_211_u2_RPBE.traj
# 656 Cu_211_u2_RPBE_no001_CO_n1_d8.traj
# 657 Cu_211_u2_RPBE_no003_CO_n3_d3.traj
# 658 Cu_211_u2_RPBE_no004_CO_n4_d3.traj
# 659 Cu_211_u2_RPBE_no005_CO_n2_d3.traj
# 660 Cu_211_u2_RPBE_no006_CO_n3_d3.traj
# 661 Cu_211_u2_RPBE_no009_CO_n2_d3.traj
# 662 Cu_211_u2_RPBE_no010_CO_n3_d3.traj
# 663 Cu_211_u2_RPBE_no012_CO_n3_d3.traj
# 664 Cu_211_u2_RPBE_no013_CO_n2_d3.traj
# 665 Cu_211_u2_RPBE_no014_CO_n1_d8.traj
# 666 Cu_211_u2_RPBE_no015_CO_n2_d3.traj
# 667 Cu_211_u2_RPBE_no016_CO_n3_d3.traj
# 668 Cu_211_u2_RPBE_no017_CO_n4_d3.traj
# 669 Cu_211_u2_RPBE_no018_CO_n2_d3.traj
# 670 Cu_211_u2_RPBE_no020_CO_n2_d3.traj
# 671 Cu_211_u2_RPBE_no021_CO_n3_d3.traj
# 672 Cu_211_u2_RPBE_no022_CO_n2_d3.traj
# 673 Cu_211_u2_RPBE_no023_CO_n3_d3.traj
# 674 Cu_211_u2_RPBE_no024_CO_n2_d3.traj
# 675 Cu_211_u2_RPBE_no025_CO_n3_d3.traj
# 676 Cu_211_u2_RPBE_no026_CO_n2_d3.traj
# 677 Cu_211_u2_RPBE_no027_CO_n1_d8.traj
# 678 Cu_211_u2_RPBE_no030_CO_n2_d3.traj
# 679 Cu_211_u2_RPBE_no031_CO_n3_d3.traj
# 680 Cu_211_u2_RPBE_no032_CO_n4_d3.traj
# 681 Cu_211_u2_RPBE_no033_CO_n2_d3.traj
# 682 Cu_211_u2_RPBE_no034_CO_n3_d3.traj
# 683 Cu_211_u2_RPBE_no035_CO_n4_d3.traj
# 684 Cu_211_u2_RPBE_no037_CO_n2_d3.traj
# 685 Cu_211_u2_RPBE_no038_CO_n2_d3.traj
# 686 Cu_211_u2_RPBE_no039_CO_n1_d8.traj
# 1183 Pt_211_u2_RPBE_no075_CO_n4_d3.traj
# 1184 Pt_211_u2_RPBE_no082_CO_n4_d3.traj
# 1185 Pt_211_u2_RPBE_no085_CO_n4_d3.traj
# 1186 Pt_211_u2_RPBE_no088_CO_n2_d3.traj
# 1187 Pt_211_u2_RPBE_no089_CO_n1_d9.traj
# 1188 Pt_211_u2_RPBE_no092_CO_n4_d3.traj
# 1189 Pt_211_u2_RPBE_no093_CO_n2_d3.traj
# 1190 Pt_211_u2_RPBE_no094_CO_n3_d3.traj
# 1191 Pt_211_u2_RPBE_no096_CO_n3_d3.traj
# 1192 Pt_211_u2_RPBE_no099_CO_n1_d9.traj
# 1193 Pt_211_u2_RPBE_no102_CO_n4_d3.traj
# 1194 Pt_211_u2_RPBE_no104_CO_n2_d3.traj
# 1195 Pt_211_u2_RPBE_no106_CO_n1_d9.traj
# 1196 Pt_211_u2_RPBE_no108_CO_n3_d3.traj
# 1197 Pt_211_u2_RPBE_no109_CO_n4_d3.traj
# 1198 Pt_211_u2_RPBE_no110_CO_n3_d3.traj
# 1199 Pt_211_u2_RPBE_no112_CO_n1_d9.traj
# 1200 Pt_211_u2_RPBE_no113_CO_n2_d3.traj
# 1201 Pt_211_u2_RPBE_no114_CO_n2_d3.traj
# 1202 Pt_211_u2_RPBE_no115_CO_n1_d9.traj

# %%
# file = 'Pt_111_u2_no23_CO_n4_d3.traj'
file = files[151]

print(file)
iatoms = init_query(file, 'local')
# ratoms = query(file, 'local')
# print(ratoms.get_potential_energy())
# Out:
# Ag_211_u2_RPBE_no090_CO_n1_d9.traj

# %%
for item in chosen:
    with open('atoms.txt', 'a') as f:
        f.write('{0}\n'.format(item))

# %%
query('Cu_110_u2_RPBE_no003_CO_n3_d3_all.traj','local')
# Out:
# Atoms(symbols='Cu16COCOCO', pbc=True, cell=[7.35447607, 5.2003999, 23.90029993], constraint=FixAtoms(indices=[0, 1, 2, 3, 4, 5, 6, 7]), calculator=SinglePointCalculator(...))

# %%
atoms = query('Cu_110_u2_RPBE.traj','local')
bareadsites = get_adsorption_sites(atoms, False)
adsites = np.array(bareadsites['all'])
struct = AseAtomsAdaptor.get_structure(atoms)
AdsorbateSiteFinder(struct).symm_reduce(adsites)
# Out:
# [array([7.35447573e+00, 1.38127679e-07, 1.58364557e+01]),
#  array([ 7.35447474,  2.60020168, 15.83648392]),
#  array([5.51585708e+00, 1.06254385e-06, 1.58364604e+01]),
#  array([ 7.35447523,  1.30010091, 15.8364698 ]),
#  array([ 5.51585659,  1.30010183, 15.83647456])]

# %%
adsites
# Out:
# array([[7.35447573e+00, 1.38127679e-07, 1.58364557e+01],
#        [3.67723843e+00, 1.98696001e-06, 1.58364652e+01],
#        [7.35447474e+00, 2.60020168e+00, 1.58364839e+01],
#        [3.67723904e+00, 2.60020010e+00, 1.58364653e+01],
#        [5.51585708e+00, 1.06254385e-06, 1.58364604e+01],
#        [7.35447523e+00, 1.30010091e+00, 1.58364698e+01],
#        [5.51585659e+00, 1.30010183e+00, 1.58364746e+01],
#        [1.83861935e+00, 1.30010012e+00, 1.58364605e+01],
#        [1.83861886e+00, 2.60020089e+00, 1.58364746e+01],
#        [5.51585689e+00, 2.60020089e+00, 1.58364746e+01],
#        [5.51585659e+00, 3.90030178e+00, 1.58364746e+01],
#        [3.67723874e+00, 3.90030100e+00, 1.58364653e+01],
#        [1.83861904e+00, 1.06254385e-06, 1.58364604e+01],
#        [1.83861935e+00, 3.90030007e+00, 1.58364605e+01],
#        [3.67723874e+00, 1.30010104e+00, 1.58364653e+01],
#        [7.35447523e+00, 3.90030086e+00, 1.58364698e+01]])

# %%
class make_adsorbed_surface():
    """
    Assuming that atoms and adsorbates are in init folder
    Name is a filename of trajectory file withought extention
    """

    def __init__(self, surfacename, adsorbatename, env='spacom'):
        self.surfacename = surfacename
        self.adsorbatename = adsorbatename
        self.initatoms = init_query(surfacename + '.traj', env='spacom')
        self.adsorbate = query(adsorbatename+'.traj', env='spacom')

    def make_surface(self, maxmole, mindist, get_only_stable=False):
        self.maxmole = maxmole
        adseles = get_all_elements(self.adsorbate)
        baresurface, initadsites = remove_adsorbate(self.initatoms, adseles)
        bareadsites = get_adsorption_sites(baresurface, False)

        allbareadsites = np.array(bareadsites['all'])
        group = create_site_group(baresurface)

        if get_only_stable:
            client = MongoClient('localhost', 27017)
            db = client.adsE_database
            collection = db.adsE_collection

            res = re.match('(.*)_(.*)_u(.*)_(.*)', self.surfacename)
            ele = res.group(1)
            face = res.group(2)
            unit = int(res.group(3))
            xc = res.group(4)
            res = re.match('(.*)_(.*)', self.adsorbatename)
            adsorbate = res.group(1)
            
            refdata = list(collection.find({'element': ele, 'face': face, 'unitlength': 2,
                                    'xc': xc, 'adsorbate': adsorbate, 'numberofads':1}))
            
            cell = baresurface.cell
            baregroups = assign_group(group, allbareadsites, cell)

            ### choose groups to be eliminated from site candidate
            eliminatedgroup = []
            for data in refdata:
                if data['isvalid'] == 'no':
                    eliminatedgroup.append(data['igroups'])
            
            ### eliminate sites candidates
            index = []
            print(allbareadsites)
            for i in range(len(baregroups)):
                if [baregroups[i]] in eliminatedgroup:
                    index.append(i)
            allbareadsites = np.delete(allbareadsites, index, axis=0)
            
        ind = []
        for i in range(len(allbareadsites)):
            for j in range(len(initadsites)):
                if np.allclose(allbareadsites[i][:2], initadsites[j][:2]):
                    ind.append(i)

        adsites = np.delete(allbareadsites, ind, 0)
        inuse = allbareadsites[ind]

        allatoms, mindistlis, numdict, molenum \
            = get_unique_surface(self.initatoms, baresurface, adsites, maxmole, mindist, initadsites, group, self.adsorbate)

        self.allatoms = allatoms
        self.mindistlis = mindistlis
        self.numdict = numdict
        self.molenum = molenum

    def write_trajectory(self, maximum=15):
        """
        This is for writing trajectory files in init folder.
        Maximum number of configurations is set. This is for each number of adsorbates.
        """
        # get index of configurations for each moleculer numbers
        index = {}
        for i in range(len(self.molenum)):
            if str(self.molenum[i]) in index.keys():
                index[str(self.molenum[i])].append(i)
            else:
                index[str(self.molenum[i])] = [i]

        # designated maxmole might not be acheived
        maxmole = int(max(self.numdict.keys()))
        for i in range(maxmole):
            for j in range(maximum):
                if index[str(i+1)]:
                    chosen = random.choice(index[str(i+1)])
                    index[str(i+1)].remove(chosen)

                    outname = self.surfacename + str('_no') + str('{0:03d}'.format(chosen+1)) + '_CO_n' + str(
                        self.molenum[i]) + str('_d') + str(int(np.ceil(self.mindistlis[i]/0.5)-3)) + '.traj'
                    print(outname)
                    outpath = initpath + str(outname)
                    self.allatoms[chosen].write(outpath)

                else:
                    break

# %%
A = make_adsorbed_surface('Cu_211_u2_RPBE','CO_RPBE')

# %%
A.make_surface(2,2.5,get_only_stable=True)
# Out:
# [[4.24610874e+00 1.30009998e+00 2.02567438e+01]
#  [4.24610874e+00 3.90029993e+00 2.02567438e+01]
#  [2.12305437e+00 2.04127717e-16 1.95061307e+01]
#  [2.12305437e+00 2.60019995e+00 1.95061307e+01]
#  [4.24610874e+00 2.60019995e+00 2.02567438e+01]
#  [3.18458156e+00 4.55034992e+00 1.98814372e+01]
#  [6.36916311e+00 4.55034992e+00 1.98814372e+01]
#  [2.12305437e+00 3.90029993e+00 1.95061307e+01]
#  [3.18458156e+00 3.25024994e+00 1.98814372e+01]
#  [6.36916311e+00 3.25024994e+00 1.98814372e+01]
#  [2.12305437e+00 1.30009998e+00 1.95061307e+01]
#  [3.18458156e+00 6.50049988e-01 1.98814372e+01]
#  [3.18458156e+00 1.95014996e+00 1.98814372e+01]
#  [4.24610874e+00 2.30944148e-15 2.02567438e+01]
#  [6.36916311e+00 6.50049988e-01 1.98814372e+01]
#  [6.36916311e+00 1.95014996e+00 1.98814372e+01]
#  [5.66147832e+00 2.60019995e+00 2.00065394e+01]
#  [2.83073916e+00 3.90029993e+00 1.97563351e+01]
#  [7.07684790e-01 3.90029993e+00 1.97563351e+01]
#  [2.83073916e+00 1.30009998e+00 1.97563351e+01]
#  [3.53842395e+00 2.60019995e+00 2.00065394e+01]
#  [3.53842395e+00 2.30944148e-15 2.00065394e+01]
#  [5.66147832e+00 0.00000000e+00 2.00065394e+01]
#  [7.07684790e-01 1.30009998e+00 1.97563351e+01]]
# [[4.24610874e+00 1.30009998e+00 2.02567438e+01]
#  [4.24610874e+00 3.90029993e+00 2.02567438e+01]
#  [4.24610874e+00 2.60019995e+00 2.02567438e+01]
#  [2.12305437e+00 3.90029993e+00 1.95061307e+01]
#  [2.12305437e+00 1.30009998e+00 1.95061307e+01]
#  [4.24610874e+00 2.30944148e-15 2.02567438e+01]]
# progress: 0/10, 0.00 min
# progress: 1/10, 0.00 min
# progress: 2/10, 0.00 min
# progress: 3/10, 0.00 min
# progress: 4/10, 0.00 min
# progress: 5/10, 0.00 min
# progress: 6/10, 0.00 min
# progress: 7/10, 0.00 min
# progress: 8/10, 0.00 min
# progress: 9/10, 0.00 min
#
# adsorbates : # of structures, {'1': 10, '2': 6}
# total structures: 16
