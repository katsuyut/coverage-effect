# %%
from MAUtil import *
from MAInit import *
from MACalc import *
from MAPost import *
import re
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

plt.rcParams["font.size"] = 14
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
figs = [20,50]
fign = [15,4]

# %%
from pymongo import MongoClient

# %%
# client = MongoClient('localhost', 27017)
# db = client.adsE_database
# collection = db.adsE_method2

# %% [markdown]
# ### prepare data for prediction ###

# %%
formulas = ['Ag', 'Al', 'Au', 'Cu', 'Pt', 'Pd', 'Ni', 'Rh']
faces = ['100', '111']

dictlis = []

for ele in formulas:
    for face in faces:
        dicte = {'formula':ele, 'face':face}
        dictlis.append(dicte)

# %%
inst = []
dfall = []
df = []
dfpred = []
dfpred_onlyformula = []

for i in range(len(dictlis)):
    try:
        du = dataset_utilizer('adsE_method2_new', **dictlis[i])
        inst.append(du)
        dfall.append(du.dfall)
        df.append(du.df)
        dfpred.append(du.dfpred)
        dfpred_onlyformula.append(du.dfpred_onlyformula)
    except:
        print('Error: {0}'.format(dictlis[i]))

# %%
covset = []
for i in range(len(dfpred)):
    covset.append(sorted(list(set(dfpred[i]['coverage']))))
# covset

# %% [markdown]
# ### Just show residue ####

# %%
xrange = np.linspace(-2, 2)
# predadsene_surf, adsElis, Eint
fig = plt.figure(figsize=(figs[0],figs[1]))
plt.rcParams["font.size"] = 16

for i in range(len(dfpred)):
    ax = fig.add_subplot(fign[0],fign[1], i+1)
    xmin = 100
    xmax = -100

    for j in range(len(covset[i])):
        if not covset[i][j]:
            continue
        data = dfpred[i][dfpred[i]['coverage'] == covset[i][j]]
        aveadsE_suratom = np.array(data['aveadsE/suratom'])
        E_residue = np.array(data['E_residue/suratom'])
        E_prepred = aveadsE_suratom - E_residue
        if not aveadsE_suratom.any():
            continue
        if xmin > np.min(aveadsE_suratom):
            xmin = np.min(aveadsE_suratom)
        if xmax < np.max(aveadsE_suratom):
            xmax = np.max(aveadsE_suratom)
        ax.plot(aveadsE_suratom, E_prepred, 'o')
   
    ax.plot(xrange, xrange, '-')

    plt.xlim(-1.5, 1.5)
    plt.ylim(-1.5, 1.5)
    ax.set_title('{}_{}'.format(dictlis[i]['formula'], dictlis[i]['face']))
#     ax.legend(['{0:.2f}'.format(item) for item in covset[i]], bbox_to_anchor=(1, 0.8))
    ax.legend(['{0:.2f}'.format(item) for item in covset[i]])
    ax.set_xlabel('DFT')
    ax.set_ylabel('E_each + E_space')
#     plt.savefig('{}_{}_predE_wCObondfix.png'.format(dictlis[i]['element'], dictlis[i]['mirror']), bbox_inches='tight')
    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.0, right=0.95, hspace=0.5, wspace=0.3)
    
    if not covset[i]:
        continue
    data = dfpred[i]
    aveadsE_suratom = np.array(data['aveadsE/suratom'])
    E_residue = np.array(data['E_residue/suratom'])
    E_prepred = aveadsE_suratom - E_residue    
    print(dictlis[i]['formula'], dictlis[i]['face'], np.sqrt(mean_squared_error(aveadsE_suratom, E_prepred)))
    
# plt.savefig('E_residue.png', bbox_inches='tight')
plt.show()
# Out:
# Ag 100 0.023114000731727445
# Ag 111 0.10886186060998215
# Al 100 0.03852199125056321
# Al 111 0.07242035334292324
# Au 100 0.06090423048770582
# Au 111 0.2354275561288555
# Cu 100 0.08283242518379592
# Cu 111 0.10006175960064963
# Pt 100 0.17901315150314273
# Pt 111 0.22181467459511078
# Pd 100 0.19773032868392085
# Pd 111 0.19252600819756988
# Ni 100 0.10614268850265127
# Ni 111 0.11136314970368909
# Rh 100 0.07986399181400822
# Rh 111 0.08916327310964357

# %%
fig = plt.figure(figsize=(figs[0],figs[1]))
plt.rcParams["font.size"] = 16


xmin = 0
xmax = 5
for i in range(len(dfpred)):
    ax = fig.add_subplot(fign[0],fign[1], i+1)
    ax.plot(dfpred[i][dfpred[i]['minimum_distance']==2]['ads_dist2'], dfpred[i][dfpred[i]['minimum_distance']==2]['E_residue/suratom'], 'o')
    ax.plot(dfpred[i][dfpred[i]['minimum_distance']==3]['ads_dist3'], dfpred[i][dfpred[i]['minimum_distance']==3]['E_residue/suratom'], 'o')
    ax.plot([xmin,xmax],[0,0], "red", linestyle='dashed') # normal way
    ax.set_title('{}_{}'.format(dictlis[i]['formula'], dictlis[i]['face']))
    ax.set_xlabel('# of nearest adsorbates')
    ax.set_ylabel('E_residue/suratom')
    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.0, right=0.95, hspace=0.5, wspace=0.3)
    plt.legend(['dist:2','dist:3'], loc='lower right')
# plt.savefig('')
  #  plt.xlim(xmin,xmax)
    plt.ylim(-1,1)
plt.show()

# %% [markdown]
# ### Parameters specific to material and face

# %%
xrange = np.linspace(-10, 10)
# predadsene_surf, adsElis, Eint
fig = plt.figure(figsize=(figs[0],figs[1]))
plt.rcParams["font.size"] = 16
mselis = []
weightslis = []
std_errslis = []

for i in range(len(dfpred)):
    ax = fig.add_subplot(fign[0],fign[1], i+1)
    xmin = 100
    xmax = -100
    try:
        weights, std_errs = inst[i].fit_weight_from_specific_formula_and_face()
        weightslis.append(weights)
        std_errslis.append(std_errs)
    except:
        weightslis.append(np.array([0,0]))
        std_errslis.append(np.array([0,0]))
        print('Data unusable')

    for j in range(len(covset[i])):
        data = dfpred[i][dfpred[i]['coverage'] == covset[i][j]]

        E_residue_pred = data['ads_dist2'] * weights[0] + data['ads_dist3'] * weights[1]
        E_ads_pred = (data['E_int_space'] + data['sumE_each_ads'])/data['surfatomnum'] + E_residue_pred

# total, not /site
#         E_ads_pred = (data['E_int_space'] + data['sumE_each_ads']) + E_residue_pred*data['surfatomnum']
#         aveadsE_suratom = data['aveadsE/suratom']*data['surfatomnum']

#         aveadsE_suratom = data['aveadsE/suratom']
        if not aveadsE_suratom.any():
            continue
        if xmin > np.min(aveadsE_suratom):
            xmin = np.min(aveadsE_suratom)
        if xmax < np.max(aveadsE_suratom):
            xmax = np.max(aveadsE_suratom)
        ax.plot(aveadsE_suratom, E_ads_pred, 'o')
    ax.plot(xrange, xrange, '-')

    plt.xlim(-1.5, 1.5)
    plt.ylim(-1.5, 1.5)
    
    plt.xlim(-6, 2)
    plt.ylim(-6, 2)
    ax.set_title('{}_{}'.format(dictlis[i]['formula'], dictlis[i]['face']))
#     ax.legend(['{0:.2f}'.format(item) for item in covset[i]], bbox_to_anchor=(1, 0.8))
    ax.legend(['{0:.2f}'.format(item) for item in covset[i]])
    ax.set_xlabel('DFT')
    ax.set_ylabel('E_predict')
#     plt.savefig('{}_{}_predE_wCObondfix.png'.format(dictlis[i]['element'], dictlis[i]['mirror']), bbox_inches='tight')
    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.0, right=0.95, hspace=0.5, wspace=0.3)
    
    if not covset[i]:
        continue
    data = dfpred[i]
    E_residue_pred = data['ads_dist2'] * weights[0] + data['ads_dist3'] * weights[1]
    E_ads_pred = (data['E_int_space'] + data['sumE_each_ads'])/data['surfatomnum'] + E_residue_pred
    aveadsE_suratom = data['aveadsE/suratom']
# total, not /site
#     E_ads_pred = (data['E_int_space'] + data['sumE_each_ads']) + E_residue_pred*data['surfatomnum']
#     aveadsE_suratom = data['aveadsE/suratom']*data['surfatomnum']

    rmse = np.sqrt(mean_squared_error(aveadsE_suratom, E_ads_pred))
    mselis.append(rmse)
    print(dictlis[i]['formula'], dictlis[i]['face'], rmse, *weights, *std_errs)

weightslis = np.array(weightslis)
std_errslis = np.array(std_errslis)
# plt.savefig('E_pred_wmf_method3.png', bbox_inches='tight')
# plt.show()
# Out:
# Ag 100 0.06615807138052059 0.0233927117155994 -0.0008789206455014601 0.00782224047592699 0.000807070854765492
# Ag 111 0.17707045173845867 0.12451407733867072 -0.009218314970286377 0.017399233192246063 0.0014477718349590679
# Al 100 0.10588835795927423 -0.014527658416896221 -0.002316465259944394 0.006075023553006505 0.0011368053302188528
# Al 111 0.14282409387541206 -0.02296416538007827 -0.004744422379048623 0.00915329868922716 0.001196188065575856
# Au 100 0.07279270339215968 0.06459780506354719 0.0015253946514975658 0.008523990610741876 0.0008758404192893085
# Au 111 0.2570860343754608 0.22742891095968554 -0.009505130288468581 0.015638628406850517 0.0018646279223920078
# Cu 100 0.230207348365982 0.048066716654456915 -0.010148742776864172 0.013416462661364948 0.0024818835857948734
# Cu 111 0.11633496069156193 0.09607302339239782 -0.006610945307707783 0.007545359166907145 0.0009785293391816952
# Pt 100 0.29732259787518034 0.11017149937304889 0.006990273352604106 0.017327933105031345 0.0032054583860596834
# Pt 111 0.16556701342787603 0.12682265471391224 0.010805922842364582 0.010490815812148474 0.00138131951292654
# Pd 100 0.2496569701949857 0.12653937577252983 0.007153614134334666 0.014615915108647837 0.002713707430386617
# Pd 111 0.12537349384696403 0.12317735560228077 0.00815239010581285 0.008459237644908017 0.0011687982424497293
# Ni 100 0.28670232220645464 0.05746312490254435 0.0021218941328557507 0.016686559782026 0.0031072545871182666
# Ni 111 0.41587428652054126 -0.012529245331558837 0.005242145451445075 0.027060169414016153 0.0038414792086017935
# Rh 100 0.2698576480211321 0.03589203213991488 -0.0001887177676368197 0.015727278404698807 0.0029093565947342663
# Rh 111 0.09150748997120652 -0.07048506443262262 0.0007870991022406866 0.006016684853770791 0.0007766850789691179

# %%
labels = []

for i in range(len(dfpred)):
    labels.append(dictlis[i]['formula'] +' '+ dictlis[i]['face'])
# dictlis[i]['element'], dictlis[i]['face']

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(12,8))
rects1 = ax.bar(x - width/2, weightslis[:,0], width, yerr = std_errslis[:,0])

# Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('weight2')
ax.set_title('Weight2')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=-45, fontsize=10)

fig.tight_layout()
plt.width = 10

plt.show()


fig, ax = plt.subplots(figsize=(12,8))
rects1 = ax.bar(x - width/2, weightslis[:,1], width, yerr = std_errslis[:,1])

# Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('weight2')
ax.set_title('Weight3')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=-45, fontsize=10)

fig.tight_layout()
plt.width = 10

plt.show()

# %% [markdown]
# ### Parameters only specific to material

# %%
xrange = np.linspace(-2, 2)
# predadsene_surf, adsElis, Eint
fig = plt.figure(figsize=(figs[0],figs[1]))
plt.rcParams["font.size"] = 16

for i in range(len(dfpred)):
    ax = fig.add_subplot(fign[0],fign[1], i+1)
    xmin = 100
    xmax = -100
#     try:
    weights, std_errs = inst[i].fit_weight_from_specific_formula()
#     except:
#         print('Data unusable')

    for j in range(len(covset[i])):
        data = dfpred[i][dfpred[i]['coverage'] == covset[i][j]]
        E_residue_pred = data['ads_dist2'] * weights[0] + data['ads_dist3'] * weights[1]
        E_ads_pred = (data['E_int_space'] + data['sumE_each_ads'])/data['surfatomnum'] + E_residue_pred

        aveadsE_suratom = data['aveadsE/suratom']
        if not aveadsE_suratom.any():
            continue
        if xmin > np.min(aveadsE_suratom):
            xmin = np.min(aveadsE_suratom)
        if xmax < np.max(aveadsE_suratom):
            xmax = np.max(aveadsE_suratom)
        ax.plot(aveadsE_suratom, E_ads_pred, 'o')
    ax.plot(xrange, xrange, '-')

    plt.xlim(-1.5, 1.5)
    plt.ylim(-1.5, 1.5)
    ax.set_title('{}_{}'.format(dictlis[i]['formula'], dictlis[i]['face']))
#     ax.legend(['{0:.2f}'.format(item) for item in covset[i]], bbox_to_anchor=(1, 0.8))
    ax.legend(['{0:.2f}'.format(item) for item in covset[i]])
    ax.set_xlabel('DFT')
    ax.set_ylabel('E_predict')
#     plt.savefig('{}_{}_predE_wCObondfix.png'.format(dictlis[i]['element'], dictlis[i]['mirror']), bbox_inches='tight')
    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.0, right=0.95, hspace=0.5, wspace=0.3)
    
    if not covset[i]:
        continue
    data = dfpred[i]
    E_residue_pred = data['ads_dist2'] * weights[0] + data['ads_dist3'] * weights[1]
    E_ads_pred = (data['E_int_space'] + data['sumE_each_ads'])/data['surfatomnum'] + E_residue_pred
    aveadsE_suratom = data['aveadsE/suratom']    
    print(dictlis[i]['formula'], dictlis[i]['face'], np.sqrt(mean_squared_error(aveadsE_suratom, E_ads_pred)), *weights, *std_errs)

# plt.savefig('E_pred_wm_method2.png', bbox_inches='tight')
# plt.show()
# Out:
# Ag 100 0.03184213286300195 0.04870512669495628 -0.005070029504915425 0.010092865534583184 0.001235325521115855
# 13  5ef4525b1fa36aa7694afeeb  Pd_111_u2_RPBE_no018_CO_n4_d3.traj     yes
# 14  5ef452601fa36aa7694afeed  Pd_111_u2_RPBE_no019_CO_n2_d3.traj     yes
# 15  5ef452651fa36aa7694afeef  Pd_111_u2_RPBE_no021_CO_n2_d3.traj     yes
# 16  5ef452691fa36aa7694afef1  Pd_111_u2_RPBE_no022_CO_n3_d3.traj     yes
# 17  5ef4526e1fa36aa7694afef3  Pd_111_u2_RPBE_no023_CO_n4_d3.traj     yes
#
#    ispredictable formula face  unitlength    xc adsorbate  numberofads  \
# 0             no      Pd  111           2  RPBE        CO            1
# 1             no      Pd  111           2  RPBE        CO            1
# 2            yes      Pd  111           2  RPBE        CO            2
# 3             no      Pd  111           2  RPBE        CO            1
# 4            yes      Pd  111           2  RPBE        CO            3
# 5             no      Pd  111           2  RPBE        CO            1
# 6            yes      Pd  111           2  RPBE        CO            4
# 7            yes      Pd  111           2  RPBE        CO            2
# 8            yes      Pd  111           2  RPBE        CO            3
# 9            yes      Pd  111           2  RPBE        CO            2
# 10           yes      Pd  111           2  RPBE        CO            2
# 11           yes      Pd  111           2  RPBE        CO            2
# 12           yes      Pd  111           2  RPBE        CO            3
# 13           yes      Pd  111           2  RPBE        CO            4
# 14           yes      Pd  111           2  RPBE        CO            2
# 15           yes      Pd  111           2  RPBE        CO            2
# 16           yes      Pd  111           2  RPBE        CO            3
# 17           yes      Pd  111           2  RPBE        CO            4
#
#     coverage  surfatomnum           E      bareE      E_ads  totaladsE  \
# 0       0.25            4  -67.317241 -51.668902 -14.485436  -1.162903
# 1       0.25            4  -67.644645 -51.668902 -14.485436  -1.490307
# 2       0.50            4  -82.376499 -51.668902 -14.485436  -1.736725
# 3       0.25            4  -67.781357 -51.668902 -14.485436  -1.627019
# 4       0.75            4  -96.907416 -51.668902 -14.485436  -1.782205
# 5       0.25            4  -67.755252 -51.668902 -14.485436  -1.600914
# 6       1.00            4 -110.957271 -51.668902 -14.485436  -1.346623
# 7       0.50            4  -83.250522 -51.668902 -14.485436  -2.610747
# 8       0.75            4  -98.602440 -51.668902 -14.485436  -3.477229
# 9       0.50            4  -83.183552 -51.668902 -14.485436  -2.543778
# 10      0.50            4  -82.902901 -51.668902 -14.485436  -2.263126
# 11      0.50            4  -83.179682 -51.668902 -14.485436  -2.539907
# 12      0.75            4  -97.901511 -51.668902 -14.485436  -2.776301
# 13      1.00            4 -111.861624 -51.668902 -14.485436  -2.250977
# 14      0.50            4  -83.410526 -51.668902 -14.485436  -2.770751
# 15      0.50            4  -83.217832 -51.668902 -14.485436  -2.578057
# 16      0.75            4  -97.991623 -51.668902 -14.485436  -2.866412
# 17      1.00            4 -111.976919 -51.668902 -14.485436  -2.366272
#
#     aveadsE/suratom  aveadsE/ads  E_int_space  sumE_each_ads  \
# 0         -0.290726    -1.162903     0.003645            NaN
# 1         -0.372577    -1.490307     0.003645            NaN
# 2         -0.434181    -0.868362     0.420280      -2.325807
# 3         -0.406755    -1.627019     0.003844            NaN
# 4         -0.445551    -0.594068     1.258196      -3.488710
# 5         -0.400229    -1.600914     0.003844            NaN
# 6         -0.336656    -0.336656     2.460827      -4.651613
# 7         -0.652687    -1.305374     0.151806      -2.763818
# 8         -0.869307    -1.159076     0.512480      -4.390837
# 9         -0.635944    -1.271889     0.152208      -2.789922
# 10        -0.565782    -1.131563     0.420281      -2.980614
# 11        -0.634977    -1.269954     0.420659      -3.254038
# 12        -0.694075    -0.925434     1.258684      -4.881057
# 13        -0.562744    -0.562744     2.461559      -6.508076
# 14        -0.692688    -1.385376     0.152026      -3.227933
# 15        -0.644514    -1.289029     0.420658      -3.201829
# 16        -0.716603    -0.955471     1.258699      -4.802743
# 17        -0.591568    -0.591568     2.461566      -6.403657
#
#     E_residue/suratom       area   density       igroups       rgroups  \
# 0                 NaN  27.437009  0.036447           [0]           [0]
# 1                 NaN  27.437009  0.036447           [1]           [1]
# 2            0.042200  27.437009  0.072894        [0, 0]        [0, 0]
# 3                 NaN  27.437009  0.036447           [2]           [2]
# 4            0.112077  27.437009  0.109341     [0, 0, 0]     [0, 0, 0]
# 5                 NaN  27.437009  0.036447           [3]           [3]
# 6            0.211041  27.437009  0.145788  [0, 0, 0, 0]  [0, 0, 0, 0]
# 7            0.000316  27.437009  0.072894        [3, 0]        [3, 0]
# 8            0.100282  27.437009  0.109341     [2, 3, 0]     [2, 3, 0]
# 9            0.023484  27.437009  0.072894        [2, 0]        [2, 0]
# 10           0.074302  27.437009  0.072894        [1, 1]        [1, 1]
# 11           0.073368  27.437009  0.072894        [2, 2]        [2, 2]
# 12           0.211518  27.437009  0.109341     [2, 2, 2]     [2, 2, 2]
# 13           0.448885  27.437009  0.145788  [2, 2, 2, 2]  [2, 2, 2, 2]
# 14           0.076289  27.437009  0.072894        [3, 2]        [3, 2]
# 15           0.050778  27.437009  0.072894        [3, 3]        [3, 3]
# 16           0.169408  27.437009  0.109341     [3, 3, 3]     [3, 3, 3]
# 17           0.393955  27.437009  0.145788  [3, 3, 3, 3]  [3, 3, 3, 3]
#
#    converged is_adsorbed kept_sites E_not_exceeded minimum_distance  \
# 0        yes         yes        yes            yes           Over 4
# 1        yes         yes        yes            yes                3
# 2        yes         yes        yes            yes                3
# 3        yes         yes        yes            yes                3
# 4        yes         yes        yes            yes                3
# 5        yes         yes        yes            yes                3
# 6        yes         yes        yes            yes                3
# 7        yes         yes        yes            yes                3
# 8        yes         yes        yes            yes                2
# 9        yes         yes        yes            yes                3
# 10       yes         yes        yes            yes                2
# 11       yes         yes        yes            yes                2
# 12       yes         yes        yes            yes                2
# 13       yes         yes        yes            yes                2
# 14       yes         yes        yes            yes                2
# 15       yes         yes        yes            yes                2
# 16       yes         yes        yes            yes                2
# 17       yes         yes        yes            yes                2
#
#     ads_dist2  ads_dist3
# 0    0.000000   0.000000
# 1    0.000000   0.500000
# 2    0.000000   4.000000
# 3    0.000000   0.666667
# 4    0.000000  12.000000
# 5    0.000000   0.666667
# 6    0.000000  24.000000
# 7    0.000000   4.666667
# 8    0.666667   9.333333
# 9    0.000000   4.666667
# 10   1.000000   1.000000
# 11   0.444444   2.222222
# 12   1.333333   4.666667
# 13   2.666667   8.000000
# 14   0.666667   1.333333
# 15   0.444444   2.222222
# 16   1.333333   4.666667
# 17   2.666667   8.000000

# %%
init_query('ZnCu_110_u2_RPBE_no004_CO_n1_d10.traj','local')
query('ZnCu_110_u2_RPBE_no004_CO_n1_d10.traj','local')
# Out:
# Atoms(symbols='Zn2Cu2Zn2Cu2Zn2Cu2Zn2Cu2Zn2Cu2Zn2Cu2Zn2Cu2Zn2Cu2CO', pbc=[True, True, False], cell=[[6.0140740590921835, 0.0, 4e-16], [1.4e-15, 8.505185099484375, 5e-16], [0.0, 0.0, 25.51555529845313]], tags=..., constraint=FixAtoms(indices=[0, 1, 2, 3, 8, 9, 10, 11, 16, 17, 18, 19, 24, 25, 26, 27]), calculator=SinglePointCalculator(...))

# %%
a = 1
dfall[a]#[dfall[a]['numberofads']==1]
# Out:
#                          _id                                name isvalid  \
# 0   5ef4321a1fa36aa7694af937  Ag_111_u2_RPBE_no001_CO_n1_d9.traj     yes
# 1   5ef432211fa36aa7694af939  Ag_111_u2_RPBE_no002_CO_n1_d9.traj     yes
# 2   5ef432281fa36aa7694af93b  Ag_111_u2_RPBE_no002_CO_n2_d3.traj     yes
# 3   5ef4322c1fa36aa7694af93d  Ag_111_u2_RPBE_no003_CO_n1_d9.traj     yes
# 4   5ef432331fa36aa7694af93f  Ag_111_u2_RPBE_no003_CO_n3_d3.traj     yes
# 5   5ef432381fa36aa7694af941  Ag_111_u2_RPBE_no004_CO_n1_d9.traj     yes
# 6   5ef4323c1fa36aa7694af943  Ag_111_u2_RPBE_no004_CO_n4_d3.traj     yes
# 7   5ef432411fa36aa7694af945  Ag_111_u2_RPBE_no005_CO_n3_d3.traj     yes
# 8   5ef432461fa36aa7694af947  Ag_111_u2_RPBE_no006_CO_n4_d3.traj      no
# 9   5ef4324e1fa36aa7694af949  Ag_111_u2_RPBE_no007_CO_n2_d3.traj      no
# 10  5ef432521fa36aa7694af94b  Ag_111_u2_RPBE_no008_CO_n3_d3.traj      no
# 11  5ef432571fa36aa7694af94d  Ag_111_u2_RPBE_no009_CO_n3_d3.traj      no
# 12  5ef4325f1fa36aa7694af94f  Ag_111_u2_RPBE_no010_CO_n3_d3.traj      no
# 13  5ef432661fa36aa7694af951  Ag_111_u2_RPBE_no011_CO_n2_d3.traj      no
# 14  5ef4326e1fa36aa7694af953  Ag_111_u2_RPBE_no012_CO_n3_d3.traj      no
# 15  5ef432751fa36aa7694af955  Ag_111_u2_RPBE_no013_CO_n2_d3.traj     yes
# 16  5ef4327a1fa36aa7694af957  Ag_111_u2_RPBE_no014_CO_n3_d3.traj     yes
# 17  5ef4327f1fa36aa7694af959  Ag_111_u2_RPBE_no015_CO_n2_d3.traj     yes
# 18  5ef432831fa36aa7694af95b  Ag_111_u2_RPBE_no017_CO_n2_d3.traj     yes
# 19  5ef4328a1fa36aa7694af95d  Ag_111_u2_RPBE_no018_CO_n3_d3.traj     yes
# 20  5ef4328f1fa36aa7694af95f  Ag_111_u2_RPBE_no019_CO_n4_d3.traj      no
# 21  5ef432971fa36aa7694af961  Ag_111_u2_RPBE_no020_CO_n2_d3.traj      no
# 22  5ef4329f1fa36aa7694af963  Ag_111_u2_RPBE_no021_CO_n3_d3.traj      no
# 23  5ef432a31fa36aa7694af965  Ag_111_u2_RPBE_no022_CO_n3_d3.traj      no
# 24  5ef432a81fa36aa7694af967  Ag_111_u2_RPBE_no023_CO_n4_d3.traj     yes
# 25  5ef432ad1fa36aa7694af969  Ag_111_u2_RPBE_no024_CO_n2_d3.traj     yes
# 26  5ef432b21fa36aa7694af96b  Ag_111_u2_RPBE_no025_CO_n2_d3.traj      no
# 27  5ef432b91fa36aa7694af96d  Ag_111_u2_RPBE_no026_CO_n2_d3.traj      no
# 28  5ef432c01fa36aa7694af96f  Ag_111_u2_RPBE_no028_CO_n2_d3.traj     yes
# 29  5ef432c81fa36aa7694af971  Ag_111_u2_RPBE_no029_CO_n2_d3.traj      no
# 30  5ef432d01fa36aa7694af973  Ag_111_u2_RPBE_no030_CO_n3_d3.traj     yes
# 31  5ef432d51fa36aa7694af975  Ag_111_u2_RPBE_no031_CO_n4_d3.traj      no
# 32  5ef432de1fa36aa7694af977  Ag_111_u2_RPBE_no033_CO_n2_d3.traj      no
# 33  5ef432e51fa36aa7694af979  Ag_111_u2_RPBE_no034_CO_n3_d3.traj     yes
# 34  5ef432ea1fa36aa7694af97b  Ag_111_u2_RPBE_no035_CO_n4_d3.traj      no
#
#    ispredictable formula face  unitlength    xc adsorbate  numberofads  \
# 0             no      Ag  111           2  RPBE        CO            1
# 1             no      Ag  111           2  RPBE        CO            1
# 2            yes      Ag  111           2  RPBE        CO            2
# 3             no      Ag  111           2  RPBE        CO            1
# 4            yes      Ag  111           2  RPBE        CO            3
# 5             no      Ag  111           2  RPBE        CO            1
# 6            yes      Ag  111           2  RPBE        CO            4
# 7            yes      Ag  111           2  RPBE        CO            3
# 8            yes      Ag  111           2  RPBE        CO            4
# 9            yes      Ag  111           2  RPBE        CO            2
# 10           yes      Ag  111           2  RPBE        CO            3
# 11           yes      Ag  111           2  RPBE        CO            3
# 12           yes      Ag  111           2  RPBE        CO            3
# 13           yes      Ag  111           2  RPBE        CO            2
# 14           yes      Ag  111           2  RPBE        CO            3
# 15           yes      Ag  111           2  RPBE        CO            2
# 16           yes      Ag  111           2  RPBE        CO            3
# 17           yes      Ag  111           2  RPBE        CO            2
# 18           yes      Ag  111           2  RPBE        CO            2
# 19           yes      Ag  111           2  RPBE        CO            3
# 20           yes      Ag  111           2  RPBE        CO            4
# 21           yes      Ag  111           2  RPBE        CO            2
# 22           yes      Ag  111           2  RPBE        CO            3
# 23           yes      Ag  111           2  RPBE        CO            3
# 24           yes      Ag  111           2  RPBE        CO            4
# 25           yes      Ag  111           2  RPBE        CO            2
# 26           yes      Ag  111           2  RPBE        CO            2
# 27           yes      Ag  111           2  RPBE        CO            2
# 28           yes      Ag  111           2  RPBE        CO            2
# 29           yes      Ag  111           2  RPBE        CO            2
# 30           yes      Ag  111           2  RPBE        CO            3
# 25           0.000471  30.745793  0.065050        [1, 1]        [1, 1]
# 26          -0.045856  30.745793  0.065050        [3, 1]        [0, 1]
# 27          -0.042253  30.745793  0.065050        [2, 1]        [0, 1]
# 28           0.076053  30.745793  0.065050        [3, 2]        [3, 2]
# 29          -0.038437  30.745793  0.065050        [2, 2]        [0, 0]
# 30           0.119226  30.745793  0.097574     [2, 2, 2]     [2, 2, 2]
# 31          -0.070898  30.745793  0.130099  [2, 2, 2, 2]  [2, 2, 2, 2]
# 32          -0.039928  30.745793  0.065050        [3, 3]        [0, 0]
# 33           0.123588  30.745793  0.097574     [3, 3, 3]     [3, 3, 3]
# 34           0.167367  30.745793  0.130099  [3, 3, 3, 3]  [3, 3, 3, 3]
#
#    converged is_adsorbed kept_sites E_not_exceeded minimum_distance  \
# 0        yes         yes        yes            yes           Over 4
# 1        yes         yes        yes            yes                3
# 2        yes         yes        yes            yes                3
# 3        yes         yes        yes            yes                3
# 4        yes         yes        yes            yes                3
# 5        yes         yes        yes            yes                3
# 6        yes         yes        yes            yes                3
# 7        yes         yes        yes            yes                3
# 8         no          no        yes            yes                2
# 9        yes         yes         no            yes                3
# 10       yes         yes         no            yes                2
# 11       yes         yes         no            yes                3
# 12       yes         yes         no            yes                3
# 13       yes         yes         no            yes                3
# 14       yes         yes         no            yes                3
# 15       yes         yes        yes            yes                3
# 16       yes         yes        yes            yes                2
# 17       yes         yes        yes            yes                3
# 18       yes         yes        yes            yes                2
# 19       yes         yes        yes            yes                2
# 20        no         yes        yes            yes                3
# 21       yes         yes         no            yes                3
# 22       yes         yes         no            yes                3
# 23       yes         yes         no            yes                3
# 24       yes         yes        yes            yes                2
# 25       yes         yes        yes            yes                3
# 26       yes         yes         no            yes                3
# 27       yes         yes         no            yes                3
# 28       yes         yes        yes            yes                2
# 29        no         yes         no            yes                3
# 30       yes         yes        yes            yes                2
# 31        no          no        yes            yes           Over 4
# 32       yes         yes         no            yes                3
# 33       yes         yes        yes            yes                2
# 34        no         yes        yes            yes                2
#
#     ads_dist2  ads_dist3
# 0    0.000000   0.000000
# 1    0.000000   0.500000
# 2    0.000000   4.000000
# 3    0.000000   0.666667
# 4    0.000000  12.000000
# 5    0.000000   0.666667
# 6    0.000000  24.000000
# 7    0.000000  12.500000
# 8    1.000000   1.000000
# 9    0.000000   4.666667
# 10   0.666667   9.333333
# 11   0.000000  12.000000
# 12   0.000000  12.500000
# 13   0.000000   4.666667
# 14   0.000000  12.500000
# 15   0.000000   4.666667
# 16   0.666667   9.333333
# 17   0.000000   4.666667
# 18   1.000000   1.000000
# 19   1.000000   9.500000
# 20   0.000000  24.000000
# 21   0.000000   4.000000
# 22   0.000000  12.000000
# 23   0.000000  12.500000
# 24   2.000000  18.000000
# 25   0.000000   5.000000
# 26   0.000000   4.666667
# 27   0.000000   4.666667
# 28   0.666667   1.333333
# 29   0.000000   4.000000
# 30   1.333333   4.666667
# 31   0.000000   0.000000
# 32   0.000000   4.000000
# 33   1.333333   4.666667
# 34   2.666667   7.666667
